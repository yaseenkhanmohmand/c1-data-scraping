# %%
import os
import re
import json
import requests
from bs4 import BeautifulSoup
import time

# %%
#provide url for fixer uppers here:
url='https://fayar.craigslist.org/search/gravette-ar/rea?hasPic=1&lat=36.4294&lon=-94.4477&min_price=100000&query=fixer%20upper&search_distance=1000#search=1~gallery~0~0'
def image_url_getter(url):
  URL=url

  headers = {
      "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:90.0) Gecko/20100101 Firefox/90.0"
  }

  response = requests.get(URL, headers=headers)

  soup = BeautifulSoup(response.content, "html.parser")

  # Assuming your soup object is named 'soup'
  links = soup.select('li.cl-static-search-result a')

  # Extract the href attribute from each link
  urls = [link['href'] for link in links]

  return urls


image_url_getter(url)
# Out:
# ['https://swmi.craigslist.org/reo/d/hartford-fixer-upper-priced-to-sell-fast/7669577246.html',
#  'https://madison.craigslist.org/reo/d/tomahawk-tomahawk-fixer-upper-spirit/7669458675.html',
#  'https://northernwi.craigslist.org/reo/d/tomahawk-tomahawk-fixer-upper-spirit/7669455498.html',
#  'https://tampa.craigslist.org/hdo/reo/d/brooksville-3-pool-home-fixer-upper-for/7659045628.html',
#  'https://boone.craigslist.org/reb/d/sugar-grove-3br-1ba-fixer-upper-in/7664858878.html',
#  'https://stillwater.craigslist.org/reo/d/guthrie-fixer-upper-country-home-with/7669312468.html',
#  'https://albuquerque.craigslist.org/reb/d/albuquerque-owner-financing-ne-heights/7659569791.html',
#  'https://tampa.craigslist.org/hdo/reo/d/brooksville-3-pool-home-fixer-upper-in/7661081129.html',
#  'https://tucson.craigslist.org/reo/d/hayden-bdr-bath-fixer-upper/7664719649.html',
#  'https://austin.craigslist.org/reb/d/austin-north-austin-fixer-upper-78727/7668926312.html',
# ...

# %%
#this will get the images and save them in a fixer_uppers folder

def images_download(url):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:90.0) Gecko/20100101 Firefox/90.0"
    }

    # Get the folder name
    folder_name = 'fixer_uppers/'+re.search(r'(\d+).html$', url).group(1)

    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Raise an error for bad responses
        soup = BeautifulSoup(response.content, 'html.parser')

        # Extracting the JavaScript array using regular expression
        script_content = soup.find('script', text=re.compile('var imgList = ')).string
        img_list_str = re.search(r'var imgList = (\[.*?\]);', script_content).group(1)

        # Parsing the extracted JSON string
        img_list = json.loads(img_list_str)

        # Getting all image URLs from the parsed JSON list
        img_urls = [img['url'] for img in img_list]

        # Create directory if it doesn't exist
        if not os.path.exists(folder_name):
            os.makedirs(folder_name)

        # Download and save each image
        for idx, img_url in enumerate(img_urls, 1):
            img_response = requests.get(img_url, headers=headers)
            img_response.raise_for_status()  # Raise an error for bad responses
            with open(f'{folder_name}/image_{idx}.jpg', 'wb') as file:
                file.write(img_response.content)

            time.sleep(0.1)  # Sleep for 1 second between image downloads

        print("Images downloaded!")

    except requests.RequestException as e:
        print(f"Error encountered: {e}")

# %%
#specify number of pages here, please note that this might not always work
#this will give us a list of all the urls for house listings.
number_of_pages=4
all_urls=[]
for i in range(number_of_pages):
  print(i)
  url=url
  print(len(all_urls))
  all_urls.extend(image_url_getter(url))
  all_urls
# Out:
# 0
# 0
# 1
# 339
# 2
# 678
# 3
# 1017

# %%
all_urls=list(set(all_urls))

#start downloading
import time
i=0
for url in all_urls:

  time.sleep(1)
  images_download(url)
  i+=1
  print(i)

# %% [markdown]
# # Starting the process for renovated now

# %%
#renovated URL here
url='https://boston.craigslist.org/search/boston-ma/rea?lat=42.3583&lon=-71.0603&min_price=100000&query=renovated&search_distance=1000#search=1~gallery~0~0'
def image_url_getter(url):
  URL=url

  headers = {
      "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:90.0) Gecko/20100101 Firefox/90.0"
  }

  response = requests.get(URL, headers=headers)

  soup = BeautifulSoup(response.content, "html.parser")

  # Assuming your soup object is named 'soup'
  links = soup.select('li.cl-static-search-result a')

  # Extract the href attribute from each link
  urls = [link['href'] for link in links]

  return urls


image_url_getter(url)
# Out:
# ['https://newyork.craigslist.org/wch/reb/d/marlboro-escape-westchesters-high-taxes/7658914243.html',
#  'https://newyork.craigslist.org/lgi/reb/d/marlboro-escape-long-islands-high/7659020525.html',
#  'https://newyork.craigslist.org/que/reb/d/jamaica-price-reductioncolonial-family/7669485437.html',
#  'https://newyork.craigslist.org/que/reb/d/jamaica-price-reductioncolonial-family/7669474345.html',
#  'https://newyork.craigslist.org/brx/reo/d/bronx-fully-renovated-family-house/7668752371.html',
#  'https://newyork.craigslist.org/brx/reo/d/bronx-fully-renovated-one-family-house/7660128471.html',
#  'https://newyork.craigslist.org/que/reo/d/jamaica-fully-renovated-one-sharmilee/7660128391.html',
#  'https://newyork.craigslist.org/brx/reo/d/bronx-fully-renovated-one-family-house/7660128561.html',
#  'https://newyork.craigslist.org/brx/reo/d/bronx-fully-renovated-one-family-house/7660121193.html',
# ...

# %%
#this will get the images and save them in a renovated folder

def images_download(url):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:90.0) Gecko/20100101 Firefox/90.0"
    }

    # Get the folder name
    folder_name = 'renovated/'+re.search(r'(\d+).html$', url).group(1)

    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Raise an error for bad responses
        soup = BeautifulSoup(response.content, 'html.parser')

        # Extracting the JavaScript array using regular expression
        script_content = soup.find('script', text=re.compile('var imgList = ')).string
        img_list_str = re.search(r'var imgList = (\[.*?\]);', script_content).group(1)

        # Parsing the extracted JSON string
        img_list = json.loads(img_list_str)

        # Getting all image URLs from the parsed JSON list
        img_urls = [img['url'] for img in img_list]

        # Create directory if it doesn't exist
        if not os.path.exists(folder_name):
            os.makedirs(folder_name)

        # Download and save each image
        for idx, img_url in enumerate(img_urls, 1):
            img_response = requests.get(img_url, headers=headers)
            img_response.raise_for_status()  # Raise an error for bad responses
            with open(f'{folder_name}/image_{idx}.jpg', 'wb') as file:
                file.write(img_response.content)

            time.sleep(0.1)  # Sleep for 1 second between image downloads

        print("Images downloaded!")

    except requests.RequestException as e:
        print(f"Error encountered: {e}")

# %%
#specify number of pages here, please note that this might not always work
#this will give us a list of all the urls for house listings.
number_of_pages=4
all_urls=[]
for i in range(number_of_pages):
  print(i)
  url=url
  print(len(all_urls))
  all_urls.extend(image_url_getter(url))
  all_urls
# Out:
# 0
# 0
# 1
# 312
# 2
# 624
# 3
# 936

# %%
all_urls=list(set(all_urls))

#start downloading
import time
i=0
for url in all_urls:

  time.sleep(1)
  images_download(url)
  i+=1
  print(i)
# Out:
# /var/folders/2n/pl2cbny56v546_dq9bh5zhlh0000gn/T/ipykernel_88072/1753132958.py:17: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   script_content = soup.find('script', text=re.compile('var imgList = ')).string
# Images downloaded!
# 1
# Images downloaded!
# 2
# Images downloaded!
# 3
# Images downloaded!
# 4
# Images downloaded!
# 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/yaseenmohmamd/Documents/harvard/scraping craigslist/second_scraper/scraping.ipynb Cell 10 line 9
#       <a href='vscode-notebook-cell:/Users/yaseenmohmamd/Documents/harvard/scraping%20craigslist/second_scraper/scraping.ipynb#X12sZmlsZQ%3D%3D?line=5'>6</a> for url in all_urls:
# ...
